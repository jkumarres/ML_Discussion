# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the grid data

# %%
xyData = open("xygrid.out","r")

XY = np.loadtxt("xygrid.out",unpack=False)

fig = plt.figure(figsize=(20, 20))
plt.plot(XY[:,0],XY[:,1],'.')
axes = plt.gca()
axes.set_aspect(1)
plt.show()

print(XY)
# Out:
# [[ 1.145496    0.        ]
#  [ 1.145638    0.00499792]
#  [ 1.145679    0.00999767]
#  ...
#  [ 1.267912   -0.01491484]
#  [ 1.26819    -0.0099226 ]
#  [ 1.268399   -0.00492706]]

# %% [markdown]
# # Question
#
# ## Generate a random point and label it as inside or outside the mesh.
